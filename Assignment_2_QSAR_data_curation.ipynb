# %% [markdown]
# # **AI And Biotechnology/Bioinformatics**
#
# ## **AI and Drug Discovery Course: QSAR Modeling**
# This notebook demonstrates how to collect and preprocess bioactivity data from ChEMBL for QSAR modeling

# %% [markdown]
# # **Part 1: Data Collection & Curation**

# %% [markdown]
# **First we need to connect Google Colab with our Google Drive, so that we can have access to our Google drive within Colab.**
#
# This allows us to:
# * Save datasets
# * Reload data across sessions
# * Organize project files

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# **Now create "data" folder in our "Colab Notebooks" folder on Google Drive.**

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %% [markdown]
# ## Install and Import Required Libraries
# We install the ChEMBL web service package so that we can retrieve bioactivity data

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.3.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.1)
# Collecting url-normalize>=2.0 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.9 MB/s eta 0:00:00
# Downloading requests_cache-1.3.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 5.9 MB/s eta 0:00:00
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 6.0 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.3.0 chembl_webresource_client-0.10.9 requests-cache-1.3.0 url-normalize-2.2.1

# %% [markdown]
# # Import Libraries
# * pandas for data handling
# * new_client from chembl for accessing the database

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # Step 1: Search for Traget Protein
#
# ## **Target Identification (KRAS)**
# Search ChEMBL for the KRAS target and select the most relevant entry.

# %%
target = new_client.target
target_query = target.search("FLT-1")
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Mus musculus
# 2               []  Homo sapiens
# 3               []  Homo sapiens
# 4               []  Homo sapiens
#
#                                            pref_name  score  \
# 0      Vascular endothelial growth factor receptor 1   19.0
# 1      Vascular endothelial growth factor receptor 1   19.0
# 2  Vascular endothelial growth factor receptor 1 ...   17.0
# 3                                        VEGFR1-VEGA   17.0
# 4        Vascular endothelial growth factor receptor   16.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL1868
# 1               False       CHEMBL3516
# 2               False    CHEMBL2111480
# 3               False    CHEMBL5482996
# 4               False    CHEMBL2095227
#
#                                    target_components        target_type  \
# 0  [{'accession': 'P17948', 'component_descriptio...     SINGLE PROTEIN
# 1  [{'accession': 'P35969', 'component_descriptio...     SINGLE PROTEIN
# 2  [{'accession': 'P17948', 'component_descriptio...  SELECTIVITY GROUP
# 3  [{'accession': 'P15692', 'component_descriptio...    PROTEIN COMPLEX
# 4  [{'accession': 'P17948', 'component_descriptio...     PROTEIN FAMILY
#
#     tax_id
# 0   9606.0
# 1  10090.0
# 2   9606.0
# 3   9606.0
# 4   9606.0

# %% [markdown]
# **Reterive Bioactivity data for selected target**

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL1868'

# %% [markdown]
# **Now retrieve only bioactivity data for target; **GTPase KRas(CHEMBL2189121)** with reported IC 50  values in nM (nanomolar) unit.**

# %%
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df1 = pd.DataFrame.from_dict(results)
df1.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       307856                  []
# 1        None             None       309314                  []
# 2        None             None       309323                  []
# 3        None             None       309330                  []
# 4        None             None       314569                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL678756  Inhibition of fms-like tyrosine kinase recepto...
# 1    CHEMBL678756  Inhibition of fms-like tyrosine kinase recepto...
# 2    CHEMBL678756  Inhibition of fms-like tyrosine kinase recepto...
# 3    CHEMBL678756  Inhibition of fms-like tyrosine kinase recepto...
# 4    CHEMBL678756  Inhibition of fms-like tyrosine kinase recepto...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                               target_pref_name  \
# 0    Homo sapiens  Vascular endothelial growth factor receptor 1
# 1    Homo sapiens  Vascular endothelial growth factor receptor 1
# 2    Homo sapiens  Vascular endothelial growth factor receptor 1
# 3    Homo sapiens  Vascular endothelial growth factor receptor 1
# 4    Homo sapiens  Vascular endothelial growth factor receptor 1
#
#   target_tax_id text_value  toid  type units    uo_units upper_value value
# 0          9606       None  None  IC50    uM  UO_0000065        None   1.0
# 1          9606       None  None  IC50    uM  UO_0000065        None   0.1
# 2          9606       None  None  IC50    uM  UO_0000065        None   3.9
# 3          9606       None  None  IC50    uM  UO_0000065        None   1.5
# 4          9606       None  None  IC50    uM  UO_0000065        None   0.7
#
# [5 rows x 46 columns]

# %%
df1.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# **Finally Save the resulting bioactivity data to a CSV file** **bioactivity_raw_data.csv**.

# %%
df1.to_csv('bioactivity_raw_data.csv', index=False)

# %% [markdown]
# **Now copy "bioactivity_raw_data.csv" file to Google Drive, in foler "data"**

# %%
! cp bioactivity_raw_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 1600
# -rw------- 1 root root  135663 Jan 30 18:14 bioactivity_preprocessed_data.csv
# -rw------- 1 root root 1502495 Feb 16 17:37 bioactivity_raw_data.csv

# %%
! head bioactivity_raw_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,307856,[],CHEMBL678756,Inhibition of fms-like tyrosine kinase receptor (Flt-1) kinase activity at a concentration of 2 uM of ATP,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OCC1CCNCC1.Cl,,,CHEMBL1135889,J Med Chem,2002.0,"{'bei': '14.39', 'le': '0.28', 'lle': '1.45', 'sei': '8.78'}",CHEMBL2448064,,CHEMBL26456,6.00,0,http://www.openphacts.org/units/Nanomolar,35681,=,1,1,=,,IC50,nM,,1000.0,CHEMBL1868,Homo sapiens,Vascular endothelial growth factor receptor 1,9606,,,IC50,uM,UO_0000065,,1.0
# ,,309314,[],CHEMBL678756,Inhibition of fms-like tyrosine kinase receptor (Flt-1) kinase activity at a concentration of 2 uM of ATP,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OCCN(C)c1ccncc1,,,CHEMBL1135889,J Med Chem,2002.0,"{'bei': '15.42', 'le': '0.30', 'lle': '1.92', 'sei': '9.67'}",CHEMBL25579,,CHEMBL25579,7.00,1,http://www.openphacts.org/units/Nanomolar,35668,=,1,1,=,,IC50,nM,,100.0,CHEMBL1868,Homo sapiens,Vascular endothelial growth factor receptor 1,9606,,,IC50,uM,UO_0000065,,0.1
# ,,309323,[],CHEMBL678756,Inhibition of fms-like tyrosine kinase receptor (Flt-1) kinase activity at a concentration of 2 uM of ATP,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc2c(Nc3ccc(C#N)cc3F)ncnc2cc1OC/C=C/CN1CCCC1,,,CHEMBL1135889,J Med Chem,2002.0,"{'bei': '12.48', 'le': '0.23', 'lle': '0.99', 'sei': '6.49'}",CHEMBL24026,,CHEMBL24026,5.41,0,http://www.openphacts.org/units/Nanomolar,35661,=,1,1,=,,IC50,nM,,3900.0,CHEMBL1868,Homo sapiens,Vascular endothelial growth factor receptor 1,9606,,,IC50,uM,UO_0000065,,3.9
# ,,309330,[],CHEMBL678756,Inhibition of fms-like tyrosine kinase receptor (Flt-1) kinase activity at a concentration of 2 uM of ATP,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OC1CCN(C)CC1,,,CHEMBL1135889,J Med Chem,2002.0,"{'bei': '13.97', 'le': '0.27', 'lle': '1.17', 'sei': '9.79'}",CHEMBL26050,,CHEMBL26050,5.82,0,http://www.openphacts.org/units/Nanomolar,35660,=,1,1,=,,IC50,nM,,1500.0,CHEMBL1868,Homo sapiens,Vascular endothelial growth factor receptor 1,9606,,,IC50,uM,UO_0000065,,1.5
# ,,314569,[],CHEMBL678756,Inhibition of fms-like tyrosine kinase receptor (Flt-1) kinase activity at a concentration of 2 uM of ATP,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc2c(Nc3ccc(C)cc3F)ncnc2cc1OCC1CCNCC1,,,CHEMBL1135889,J Med Chem,2002.0,"{'bei': '15.52', 'le': '0.29', 'lle': '1.94', 'sei': '9.01'}",CHEMBL428534,,CHEMBL428534,6.16,0,http://www.openphacts.org/units/Nanomolar,35679,=,1,1,=,,IC50,nM,,700.0,CHEMBL1868,Homo sapiens,Vascular endothelial growth factor receptor 1,9606,,,IC50,uM,UO_0000065,,0.7
# ,,316937,[],CHEMBL678756,Inhibition of fms-like tyrosine kinase receptor (Flt-1) kinase activity at a concentration of 2 uM of ATP,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCn1ccnn1,,,CHEMBL1135889,J Med Chem,2002.0,"{'bei': '13.40', 'le': '0.29', 'lle': '2.20', 'sei': '7.08'}",CHEMBL281872,ZD-4190 FREE BASE,CHEMBL281872,6.16,1,http://www.openphacts.org/units/Nanomolar,35685,=,1,1,=,,IC50,nM,,700.0,CHEMBL1868,Homo sapiens,Vascular endothelial growth factor receptor 1,9606,,,IC50,uM,UO_0000065,,0.7
# ,,316965,[],CHEMBL678756,Inhibition of fms-like tyrosine kinase receptor (Flt-1) kinase activity at a concentration of 2 uM of ATP,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc2c(Nc3ccc(C)cc3F)ncnc2cc1OCC1CCN(C)CC1,,,CHEMBL1135889,J Med Chem,2002.0,"{'bei': '15.35', 'le': '0.29', 'lle': '1.75', 'sei': '10.59'}",CHEMBL281990,,CHEMBL281990,6.30,0,http://www.openphacts.org/units/Nanomolar,35656,=,1,1,=,,IC50,nM,,500.0,CHEMBL1868,Homo sapiens,Vascular endothelial growth factor receptor 1,9606,,,IC50,uM,UO_0000065,,0.5
# ,,316972,[],CHEMBL678756,Inhibition of fms-like tyrosine kinase receptor (Flt-1) kinase activity at a concentration of 2 uM of ATP,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc2c(Nc3c(F)cc(Cl)cc3F)ncnc2cc1OCC1CCN(C)CC1,,,CHEMBL1135889,J Med Chem,2002.0,"{'bei': '14.53', 'le': '0.29', 'lle': '1.49', 'sei': '10.96'}",CHEMBL422758,,CHEMBL422758,6.52,0,http://www.openphacts.org/units/Nanomolar,35682,=,1,1,=,,IC50,nM,,300.0,CHEMBL1868,Homo sapiens,Vascular endothelial growth factor receptor 1,9606,,,IC50,uM,UO_0000065,,0.3
# ,,316979,[],CHEMBL678756,Inhibition of fms-like tyrosine kinase receptor (Flt-1) kinase activity at a concentration of 2 uM of ATP,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc2c(Nc3c(F)cc(Cl)cc3F)ncnc2cc1OCC1CCNCC1,,,CHEMBL1135889,J Med Chem,2002.0,"{'bei': '14.59', 'le': '0.29', 'lle': '1.66', 'sei': '9.29'}",CHEMBL25450,,CHEMBL25450,6.35,0,http://www.openphacts.org/units/Nanomolar,35678,=,1,1,=,,IC50,nM,,450.0,CHEMBL1868,Homo sapiens,Vascular endothelial growth factor receptor 1,9606,,,IC50,uM,UO_0000065,,0.45

# %% [markdown]
# # **Step 3: Bioactivity Data Retrieval (IC50)**
# **Retrieve bioactivity data (IC50) for the selected KRAS target.**

# %% [markdown]
# **Inspect Missing Values**

# %%
df1["standard_type"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Filter Rows with Valid Bioactivity Values**

# %%
df2 = df1[df1["standard_value"].notna()]
df2.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       307856                  []
# 1        None             None       309314                  []
# 2        None             None       309323                  []
# 3        None             None       309330                  []
# 4        None             None       314569                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL678756  Inhibition of fms-like tyrosine kinase recepto...
# 1    CHEMBL678756  Inhibition of fms-like tyrosine kinase recepto...
# 2    CHEMBL678756  Inhibition of fms-like tyrosine kinase recepto...
# 3    CHEMBL678756  Inhibition of fms-like tyrosine kinase recepto...
# 4    CHEMBL678756  Inhibition of fms-like tyrosine kinase recepto...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                               target_pref_name  \
# 0    Homo sapiens  Vascular endothelial growth factor receptor 1
# 1    Homo sapiens  Vascular endothelial growth factor receptor 1
# 2    Homo sapiens  Vascular endothelial growth factor receptor 1
# 3    Homo sapiens  Vascular endothelial growth factor receptor 1
# 4    Homo sapiens  Vascular endothelial growth factor receptor 1
#
#   target_tax_id text_value  toid  type units    uo_units upper_value value
# 0          9606       None  None  IC50    uM  UO_0000065        None   1.0
# 1          9606       None  None  IC50    uM  UO_0000065        None   0.1
# 2          9606       None  None  IC50    uM  UO_0000065        None   3.9
# 3          9606       None  None  IC50    uM  UO_0000065        None   1.5
# 4          9606       None  None  IC50    uM  UO_0000065        None   0.7
#
# [5 rows x 46 columns]

# %% [markdown]
# **Assign Bioactivity Classes**
# Define active, intermediate, and inactive classes based on IC50 values.

# %%
bioactivity_class = []
for value in df2.standard_value:
    value = float(value)
    if value >= 10000:
        bioactivity_class.append("inactive")
    elif value <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %% [markdown]
# **Extract Relevant Columns**

# %%
molecule_ids = df2.molecule_chembl_id.tolist()
canonical_smiles = df2.canonical_smiles.tolist()
standard_values = df2.standard_value.tolist()

# %%
data = list(zip(
    molecule_ids,
    canonical_smiles,
    standard_values,
        bioactivity_class,
))

# %% [markdown]
# **Create Preprocessed bioactivity Dataset**

# %%
df3 = pd.DataFrame(
    data,
    columns=[
        "molecule_chembl_id",
        "canonical_smiles",
        "standard_value",
        "bioactivity_class",
    ]
)
df3.head()
# Out:
#   molecule_chembl_id                                  canonical_smiles  \
# 0      CHEMBL2448064     COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OCC1CCNCC1.Cl
# 1        CHEMBL25579   COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OCCN(C)c1ccncc1
# 2        CHEMBL24026  COc1cc2c(Nc3ccc(C#N)cc3F)ncnc2cc1OC/C=C/CN1CCCC1
# 3        CHEMBL26050      COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OC1CCN(C)CC1
# 4       CHEMBL428534         COc1cc2c(Nc3ccc(C)cc3F)ncnc2cc1OCC1CCNCC1
#
#   standard_value bioactivity_class
# 0         1000.0            active
# 1          100.0            active
# 2         3900.0      intermediate
# 3         1500.0      intermediate
# 4          700.0            active

# %% [markdown]
# **Remove Compounds without Valid SMILES**. Drop rows with **NaN**, **empty** or **None** SMILES values.

# %%
df3 = df3.dropna(subset=["canonical_smiles"])
df3 = df3[df3["canonical_smiles"].str.lower() != "none"]
df3 = df3[df3["canonical_smiles"].str.strip() != ""]
df3.head()
# Out:
#   molecule_chembl_id                                  canonical_smiles  \
# 0      CHEMBL2448064     COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OCC1CCNCC1.Cl
# 1        CHEMBL25579   COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OCCN(C)c1ccncc1
# 2        CHEMBL24026  COc1cc2c(Nc3ccc(C#N)cc3F)ncnc2cc1OC/C=C/CN1CCCC1
# 3        CHEMBL26050      COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OC1CCN(C)CC1
# 4       CHEMBL428534         COc1cc2c(Nc3ccc(C)cc3F)ncnc2cc1OCC1CCNCC1
#
#   standard_value bioactivity_class
# 0         1000.0            active
# 1          100.0            active
# 2         3900.0      intermediate
# 3         1500.0      intermediate
# 4          700.0            active

# %% [markdown]
# **Save Preprocessed Bioactivity Data.** Save the cleaned dataset to CSV and copy to Google Drive.

# %%
df3.to_csv("bioactivity_preprocessed_data.csv", index=False)

# !cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
# !ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_preprocessed_data.csv  bioactivity_raw_data.csv

# %% [markdown]
# ## **End of Part 1: Data Collection and Curation**
